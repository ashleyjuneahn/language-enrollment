# %%
 import pandas as pd
import numpy as np
import plotly.express as px

# %%
lang_df = pd.read_csv('Language enrollment.csv')

# %%
lang_df.head(3)
# Out:
#    INST_ID  SRVY_YEAR  TERM    YR&TERM            UNIV CAMPUS  NCES_ID  \
# 0   5210.0       1958  Fall  1958 Fall  A&M C OF TEXAS    NaN   228723
# 1   5210.0       1958  Fall  1958 Fall  A&M C OF TEXAS    NaN   228723
# 2   5210.0       1958  Fall  1958 Fall  A&M C OF TEXAS    NaN   228723
#
#                              UNIV_NAME_HISTORY             CITY  STATE_ID  \
# 0  A&M C of Texas renamed Texas A&M U in 1963.  College Station      44.0
# 1  A&M C of Texas renamed Texas A&M U in 1963.  College Station      44.0
# 2  A&M C of Texas renamed Texas A&M U in 1963.  College Station      44.0
#
#    ... UNDERGRAD_1_2  UNDERGRAD_3_4  UNDERGRAD_TOTAL GRAD_TOTAL  \
# 0  ...           NaN            NaN             86.0        NaN
# 1  ...           NaN            NaN            148.0        NaN
# 2  ...           NaN            NaN             66.0        NaN
#
#    ALL_LEVEL_TOTAL  LANG_REGION  OTHER_LANG  GEOGRAPHY_CODE  N_RESP ZERO_ERL
# 0             86.0            E         NaN             4.0     NaN      NaN
# 1            148.0            E         NaN             4.0     NaN      NaN
# 2             66.0            E         NaN             4.0     NaN      NaN
#
# [3 rows x 24 columns]

# %%
lang_df.columns
# Out:
# Index(['INST_ID', 'SRVY_YEAR', 'TERM', 'YR&TERM', 'UNIV', 'CAMPUS', 'NCES_ID',
#        'UNIV_NAME_HISTORY', 'CITY', 'STATE_ID', 'STATE', 'MLA ICLEVEL',
#        'LANG_CODE', 'LANGUAGE', 'UNDERGRAD_1_2', 'UNDERGRAD_3_4',
#        'UNDERGRAD_TOTAL', 'GRAD_TOTAL', 'ALL_LEVEL_TOTAL', 'LANG_REGION',
#        'OTHER_LANG', 'GEOGRAPHY_CODE', 'N_RESP', 'ZERO_ERL'],
#       dtype='object')

# %%
np.sum(lang_df['GRAD_TOTAL'])
# Out:
# 552234.0

# %%
lang_years_df = lang_df.groupby('SRVY_YEAR', as_index = False).agg({'ALL_LEVEL_TOTAL': 'sum'}).rename(columns={'SRVY_YEAR':'Year', 'ALL_LEVEL_TOTAL': 'Enrollment in languages'})
lang_years_df
# Out:
#     Year  Enrollment in languages
# 0   1958                 433639.0
# 1   1959                 537927.0
# 2   1960                 612626.0
# 3   1961                 656607.0
# 4   1963                 821271.0
# 5   1965                1034651.0
# 6   1968                1124021.0
# 7   1969                 141901.0
# 8   1970                1153239.0
# 9   1971                 137615.0
# 10  1972                1007709.0
# 11  1974                 946310.0
# 12  1977                 934305.0
# 13  1980                 924337.0
# 14  1983                 965187.0
# 15  1986                1003173.0
# 16  1990                1185465.0
# 17  1995                1138772.0
# 18  1998                1186632.0
# 19  2002                1395807.0
# 20  2006                1575838.0
# 21  2009                1673566.0
# 22  2013                1561131.0
# 23  2016                1618859.0

# %% [markdown]
# -6.7% increase 2009-2013
#
# 3.7% increase 2013-2016

# %%
lang_everything = lang_df.groupby(['SRVY_YEAR', 'LANGUAGE'], as_index = False).agg({'ALL_LEVEL_TOTAL': 'sum'}).rename(columns={'SRVY_YEAR':'Year', 'ALL_LEVEL_TOTAL': 'Enrollment in languages'})
lang_2009= lang_everything[lang_everything['Year'] == 2009]
lang_2016= lang_everything[lang_everything['Year'] == 2016]

# %%
#All languages in 2009 with enrollment above 5000
lang_2009 = lang_2009[lang_2009['Enrollment in languages'] > 5000]
lang_2009 = lang_2009[['LANGUAGE', 'Enrollment in languages']]
lang_2009
# Out:
#                           LANGUAGE  Enrollment in languages
# 2214  AMERICAN SIGN LANGUAGE (ASL)                  92068.0
# 2218                        ARABIC                  34908.0
# 2255                       CHINESE                  59876.0
# 2282                        FRENCH                 215244.0
# 2287                        GERMAN                  95613.0
# 2293                GREEK, ANCIENT                  20033.0
# 2303              HEBREW, BIBLICAL                  13758.0
# 2305                HEBREW, MODERN                   8307.0
# 2323                       ITALIAN                  80322.0
# 2324                      JAPANESE                  72357.0
# 2333                        KOREAN                   8449.0
# 2337                         LATIN                  32446.0
# 2375                    PORTUGUESE                  11273.0
# 2381                       RUSSIAN                  26740.0
# 2402                       SPANISH                 861015.0

# %%
#All languages in 2016 with enrollment above 5000
lang_2016 = lang_2016[lang_2016['Enrollment in languages'] > 5000]
lang_2016 = lang_2016[['LANGUAGE', 'Enrollment in languages']]
lang_2016
# Out:
#                           LANGUAGE  Enrollment in languages
# 2713  AMERICAN SIGN LANGUAGE (ASL)                 126030.0
# 2718                        ARABIC                  34171.0
# 2760                       CHINESE                  58102.0
# 2792                        FRENCH                 193134.0
# 2798                        GERMAN                  87798.0
# 2807                GREEK, ANCIENT                  11790.0
# 2818              HEBREW, BIBLICAL                  10391.0
# 2820                HEBREW, MODERN                   6005.0
# 2841                       ITALIAN                  61711.0
# 2842                      JAPANESE                  75229.0
# 2854                        KOREAN                  15072.0
# 2858                         LATIN                  26300.0
# 2907                    PORTUGUESE                  10596.0
# 2916                       RUSSIAN                  23044.0
# 2936                       SPANISH                 836280.0

# %%
#Percent increase from 2009 to 2016 for languages with enrollment above 5000
compare_all = lang_2009.merge(lang_2016, on='LANGUAGE', how='inner').rename(columns={'Enrollment in languages_x': '2009', 'Enrollment in languages_y': '2016'})
compare_all['Percent increase'] = ((compare_all['2016'] - compare_all['2009'])/compare_all['2009']) * 100

# %%
compare_all.sort_values(by = ['Percent increase'], ascending=False, inplace=True)
compare_all.reset_index(inplace = True)
compare_all = compare_all[['LANGUAGE', '2009', '2016', 'Percent increase']]

# %%
compare_all
# Out:
#                         LANGUAGE      2009      2016  Percent increase
# 0                         KOREAN    8449.0   15072.0         78.387975
# 1   AMERICAN SIGN LANGUAGE (ASL)   92068.0  126030.0         36.887952
# 2                       JAPANESE   72357.0   75229.0          3.969208
# 3                         ARABIC   34908.0   34171.0         -2.111264
# 4                        SPANISH  861015.0  836280.0         -2.872772
# 5                        CHINESE   59876.0   58102.0         -2.962790
# 6                     PORTUGUESE   11273.0   10596.0         -6.005500
# 7                         GERMAN   95613.0   87798.0         -8.173575
# 8                         FRENCH  215244.0  193134.0        -10.272063
# 9                        RUSSIAN   26740.0   23044.0        -13.821990
# 10                         LATIN   32446.0   26300.0        -18.942242
# 11                       ITALIAN   80322.0   61711.0        -23.170489
# 12              HEBREW, BIBLICAL   13758.0   10391.0        -24.473034
# 13                HEBREW, MODERN    8307.0    6005.0        -27.711569
# 14                GREEK, ANCIENT   20033.0   11790.0        -41.147107

# %% [markdown]
# After Korean, ASL was the next fastest growing widely learned language from 2009 to 2016. ASL enrollment grew 37% within this time span.

# %%
lang_df['LANGUAGE'].nunique()
# Out:
# 432

# %%
fig = px.scatter(lang_years_df, x="Year", y="Enrollment in languages", title='College Student Enrollment in Language Courses')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="48ace68d-b939-4a90-8bb1-1f8b9f27ded0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("48ace68d-b939-4a90-8bb1-1f8b9f27ded0")) {                    Plotly.newPlot(                        "48ace68d-b939-4a90-8bb1-1f8b9f27ded0",                        [{"hovertemplate":"Year=%{x}<br>Enrollment in languages=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[1958,1959,1960,1961,1963,1965,1968,1969,1970,1971,1972,1974,1977,1980,1983,1986,1990,1995,1998,2002,2006,2009,2013,2016],"xaxis":"x","y":[433639.0,537927.0,612626.0,656607.0,821271.0,1034651.0,1124021.0,141901.0,1153239.0,137615.0,1007709.0,946310.0,934305.0,924337.0,965187.0,1003173.0,1185465.0,1138772.0,1186632.0,1395807.0,1575838.0,1673566.0,1561131.0,1618859.0],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":"" ...

# %%
lang_df[lang_df['LANGUAGE'] == 'KOREAN']['LANG_CODE'].unique()
#Korean LANG_CODE is 47.0
# Out:
# array([47.])

# %%
np.sum(lang_df['LANG_CODE'] == 47.0)
##check if total matches below cell
# Out:
# 1192

# %%
np.sum(lang_df['LANGUAGE'] == 'KOREAN')
##1192 entries of Korean
# Out:
# 1192

# %%
kor_df = lang_df[lang_df['LANG_CODE'] == 47.0]

# %%
kor_years_df = kor_df.groupby('SRVY_YEAR', as_index = False).agg({'ALL_LEVEL_TOTAL': 'sum'}).rename(columns={'SRVY_YEAR':'Year', 'ALL_LEVEL_TOTAL': 'Enrollment in Korean'})
kor_years_df = kor_years_df.merge(lang_years_df, on='Year', how='right')

# %%
kor_years_df['Enrollment in Korean'] = kor_years_df['Enrollment in Korean'].fillna(0)

# %%
kor_years_df['Korean percent'] = (kor_years_df['Enrollment in Korean']/kor_years_df['Enrollment in languages'])*100

# %%
kor_years_df
# Out:
#     Year  Enrollment in Korean  Enrollment in languages  Korean percent
# 0   1958                  26.0                 433639.0        0.005996
# 1   1959                  25.0                 537927.0        0.004647
# 2   1960                 168.0                 612626.0        0.027423
# 3   1961                 190.0                 656607.0        0.028937
# 4   1963                 182.0                 821271.0        0.022161
# 5   1965                  82.0                1034651.0        0.007925
# 6   1968                  70.0                1124021.0        0.006228
# 7   1969                  13.0                 141901.0        0.009161
# 8   1970                 101.0                1153239.0        0.008758
# 9   1971                  25.0                 137615.0        0.018167
# 10  1972                   0.0                1007709.0        0.000000
# 11  1974                  87.0                 946310.0        0.009194
# 12  1977                 163.0                 934305.0        0.017446
# 13  1980                 365.0                 924337.0        0.039488
# 14  1983                 660.0                 965187.0        0.068381
# 15  1986                 875.0                1003173.0        0.087223
# 16  1990                2375.0                1185465.0        0.200343
# 17  1995                3343.0                1138772.0        0.293562
# 18  1998                4479.0                1186632.0        0.377455
# 19  2002                5211.0                1395807.0        0.373332
# 20  2006                7146.0                1575838.0        0.453473
# 21  2009                8449.0                1673566.0        0.504850
# 22  2013               12256.0                1561131.0        0.785072
# 23  2016               15072.0                1618859.0        0.931026

# %% [markdown]
# 45% increase 2009-2013
#
# 23% increase 2013-2016

# %% [markdown]
# **Slight** discrepency in 2013: NPR reported in 2015 that the year 2013 had enrollment at 12,229 rather than 12,256. Not sure how...

# %%
fig = px.scatter(kor_years_df, x="Year", y="Enrollment in Korean", title='College Student Enrollment in Korean Language')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="a07ed639-3469-4dbe-b94b-1d9bb0ef68d9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a07ed639-3469-4dbe-b94b-1d9bb0ef68d9")) {                    Plotly.newPlot(                        "a07ed639-3469-4dbe-b94b-1d9bb0ef68d9",                        [{"hovertemplate":"Year=%{x}<br>Enrollment in Korean=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[1958,1959,1960,1961,1963,1965,1968,1969,1970,1971,1974,1977,1980,1983,1986,1990,1995,1998,2002,2006,2009,2013,2016],"xaxis":"x","y":[26.0,25.0,168.0,190.0,182.0,82.0,70.0,13.0,101.0,25.0,87.0,163.0,365.0,660.0,875.0,2375.0,3343.0,4479.0,5211.0,7146.0,8449.0,12256.0,15072.0],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parc ...

# %%
fig = px.scatter(kor_years_df, x="Year", y="Korean percent", title='Percent of students studying a language enrolled in Korean')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="e2cc94df-be96-4c89-992d-7b34d42bd8e2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e2cc94df-be96-4c89-992d-7b34d42bd8e2")) {                    Plotly.newPlot(                        "e2cc94df-be96-4c89-992d-7b34d42bd8e2",                        [{"hovertemplate":"Year=%{x}<br>Korean percent=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[1958,1959,1960,1961,1963,1965,1968,1969,1970,1971,1972,1974,1977,1980,1983,1986,1990,1995,1998,2002,2006,2009,2013,2016],"xaxis":"x","y":[0.005995770675608052,0.004647470753466549,0.02742293014008547,0.028936639420536182,0.02216077275345166,0.007925377736067524,0.006227641654381902,0.009161316692623732,0.008757941762288649,0.018166624277876686,0.0,0.009193604632731346,0.017446123054034816,0.03948776258009795,0.06838053144105753,0.08722324065739409,0.20034332519306772,0.29356183678559006,0.3774548469955302,0.37333241630110753,0.4534730092814109,0.5048501224331756,0.7850718485508263,0.931026111600825],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"# ...

# %%
kor_colleges_df = kor_df.groupby('SRVY_YEAR', as_index = False)['UNIV'].nunique().rename(columns={'SRVY_YEAR':'Year', 'UNIV': 'Number of colleges offering Korean'})
kor_colleges_df = kor_colleges_df.merge(lang_years_df, on='Year', how='right')[['Year', 'Number of colleges offering Korean']]
kor_colleges_df['Number of colleges offering Korean'] = kor_colleges_df['Number of colleges offering Korean'].fillna(0)

# %%
kor_colleges_df
# Out:
#     Year  Number of colleges offering Korean
# 0   1958                                 1.0
# 1   1959                                 1.0
# 2   1960                                 7.0
# 3   1961                                 1.0
# 4   1963                                 1.0
# 5   1965                                 9.0
# 6   1968                                 7.0
# 7   1969                                 1.0
# 8   1970                                 1.0
# 9   1971                                 1.0
# 10  1972                                 0.0
# 11  1974                                 8.0
# 12  1977                                10.0
# 13  1980                                16.0
# 14  1983                                23.0
# 15  1986                                30.0
# 16  1990                                50.0
# 17  1995                                72.0
# 18  1998                                77.0
# 19  2002                               102.0
# 20  2006                               125.0
# 21  2009                               147.0
# 22  2013                               162.0
# 23  2016                               171.0

# %%
fig = px.scatter(kor_colleges_df, x="Year", y="Number of colleges offering Korean", title='Number of colleges offering Korean Language')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="48e89f18-1cfe-4ee9-a649-535f76183623" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("48e89f18-1cfe-4ee9-a649-535f76183623")) {                    Plotly.newPlot(                        "48e89f18-1cfe-4ee9-a649-535f76183623",                        [{"hovertemplate":"Year=%{x}<br>Number of colleges offering Korean=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[1958,1959,1960,1961,1963,1965,1968,1969,1970,1971,1972,1974,1977,1980,1983,1986,1990,1995,1998,2002,2006,2009,2013,2016],"xaxis":"x","y":[1.0,1.0,7.0,1.0,1.0,9.0,7.0,1.0,1.0,1.0,0.0,8.0,10.0,16.0,23.0,30.0,50.0,72.0,77.0,102.0,125.0,147.0,162.0,171.0],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}], ...

# %%
lang_df[lang_df['LANGUAGE'] == 'CHINESE']['LANG_CODE'].unique()
##Chinese LANG_CODE is 43.0
# Out:
# array([43.])

# %%
chin_df = lang_df[lang_df['LANG_CODE'] == 43.0]
len(chin_df)
#7337 entries of Chinese
# Out:
# 7337

# %%
chin_years_df = chin_df.groupby('SRVY_YEAR', as_index = False).agg({'ALL_LEVEL_TOTAL': 'sum'}).rename(columns={'SRVY_YEAR':'Year', 'ALL_LEVEL_TOTAL': 'Enrollment in Chinese'})

# %%
chin_years_df
# Out:
#     Year  Enrollment in Chinese
# 0   1958                  615.0
# 1   1959                  959.0
# 2   1960                  679.0
# 3   1961                 2200.0
# 4   1963                 2444.0
# 5   1965                 3359.0
# 6   1968                 5061.0
# 7   1969                  685.0
# 8   1970                 6115.0
# 9   1971                  953.0
# 10  1974                10576.0
# 11  1977                 9798.0
# 12  1980                11366.0
# 13  1983                13178.0
# 14  1986                16891.0
# 15  1990                19427.0
# 16  1995                26471.0
# 17  1998                28456.0
# 18  2002                34153.0
# 19  2006                51382.0
# 20  2009                59876.0
# 21  2013                61084.0
# 22  2016                58102.0

# %% [markdown]
# 2% increase 2009-2013
#
# -4.9% increase 2013-2016

# %%
fig = px.scatter(chin_years_df, x="Year", y="Enrollment in Chinese", title='College Student Enrollment in Chinese Language')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="f5011e0f-190b-41db-8ed7-931a156beacd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f5011e0f-190b-41db-8ed7-931a156beacd")) {                    Plotly.newPlot(                        "f5011e0f-190b-41db-8ed7-931a156beacd",                        [{"hovertemplate":"Year=%{x}<br>Enrollment in Chinese=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[1958,1959,1960,1961,1963,1965,1968,1969,1970,1971,1974,1977,1980,1983,1986,1990,1995,1998,2002,2006,2009,2013,2016],"xaxis":"x","y":[615.0,959.0,679.0,2200.0,2444.0,3359.0,5061.0,685.0,6115.0,953.0,10576.0,9798.0,11366.0,13178.0,16891.0,19427.0,26471.0,28456.0,34153.0,51382.0,59876.0,61084.0,58102.0],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth" ...

# %%
chin_colleges_df = chin_df.groupby('SRVY_YEAR', as_index = False)['UNIV'].nunique().rename(columns={'SRVY_YEAR':'Year', 'UNIV': 'Number of colleges offering Chinese'})
chin_colleges_df
# Out:
#     Year  Number of colleges offering Chinese
# 0   1958                                    1
# 1   1959                                    2
# 2   1960                                   21
# 3   1961                                    1
# 4   1963                                    1
# 5   1965                                   80
# 6   1968                                  111
# 7   1969                                   15
# 8   1970                                    1
# 9   1971                                    1
# 10  1974                                  180
# 11  1977                                  203
# 12  1980                                  219
# 13  1983                                  243
# 14  1986                                  331
# 15  1990                                  412
# 16  1995                                  393
# 17  1998                                  422
# 18  2002                                  543
# 19  2006                                  659
# 20  2009                                  819
# 21  2013                                  923
# 22  2016                                  881

# %%
fig = px.scatter(chin_colleges_df, x="Year", y="Number of colleges offering Chinese", title='Number of colleges offering Chinese')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="5166d891-5241-42bc-b7de-eb3c8d79b7d3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5166d891-5241-42bc-b7de-eb3c8d79b7d3")) {                    Plotly.newPlot(                        "5166d891-5241-42bc-b7de-eb3c8d79b7d3",                        [{"hovertemplate":"Year=%{x}<br>Number of colleges offering Chinese=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[1958,1959,1960,1961,1963,1965,1968,1969,1970,1971,1974,1977,1980,1983,1986,1990,1995,1998,2002,2006,2009,2013,2016],"xaxis":"x","y":[1,2,21,1,1,80,111,15,1,1,180,203,219,243,331,412,393,422,543,659,819,923,881],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}] ...

# %%
lang_df[lang_df['LANGUAGE'] == 'JAPANESE']['LANG_CODE'].unique()
##Japanese LANG_CODE is 42.0
# Out:
# array([42.])

# %%
jap_df = lang_df[lang_df['LANG_CODE'] == 42.0]
len(jap_df)
#7857 entries of Japanese
# Out:
# 7857

# %%
jap_years_df = jap_df.groupby('SRVY_YEAR', as_index = False).agg({'ALL_LEVEL_TOTAL': 'sum'}).rename(columns={'SRVY_YEAR':'Year', 'ALL_LEVEL_TOTAL': 'Enrollment in Japanese'})
jap_years_df
# Out:
#     Year  Enrollment in Japanese
# 0   1958                   844.0
# 1   1959                  1271.0
# 2   1960                  1754.0
# 3   1961                  1976.0
# 4   1963                  2718.0
# 5   1965                  3505.0
# 6   1968                  4322.0
# 7   1969                   568.0
# 8   1970                  6620.0
# 9   1971                   760.0
# 10  1974                  9604.0
# 11  1977                 10721.0
# 12  1980                 11516.0
# 13  1983                 16126.0
# 14  1986                 23454.0
# 15  1990                 45830.0
# 16  1995                 44723.0
# 17  1998                 43141.0
# 18  2002                 52238.0
# 19  2006                 65410.0
# 20  2009                 72357.0
# 21  2013                 66771.0
# 22  2016                 75229.0

# %% [markdown]
# -7.7% increase 2009-2013
#
# 12.7% increase 2013-2016

# %%
fig = px.scatter(jap_years_df, x="Year", y="Enrollment in Japanese", title='College Student Enrollment in Japanese Language')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="d42ce4a8-e8cf-4a1c-83ff-0df95907e064" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d42ce4a8-e8cf-4a1c-83ff-0df95907e064")) {                    Plotly.newPlot(                        "d42ce4a8-e8cf-4a1c-83ff-0df95907e064",                        [{"hovertemplate":"Year=%{x}<br>Enrollment in Japanese=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[1958,1959,1960,1961,1963,1965,1968,1969,1970,1971,1974,1977,1980,1983,1986,1990,1995,1998,2002,2006,2009,2013,2016],"xaxis":"x","y":[844.0,1271.0,1754.0,1976.0,2718.0,3505.0,4322.0,568.0,6620.0,760.0,9604.0,10721.0,11516.0,16126.0,23454.0,45830.0,44723.0,43141.0,52238.0,65410.0,72357.0,66771.0,75229.0],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewid ...

# %%
jap_colleges_df = jap_df.groupby('SRVY_YEAR', as_index = False)['UNIV'].nunique().rename(columns={'SRVY_YEAR':'Year', 'UNIV': 'Number of colleges offering Japanese'})
jap_colleges_df
# Out:
#     Year  Number of colleges offering Japanese
# 0   1958                                     1
# 1   1959                                     2
# 2   1960                                    32
# 3   1961                                     1
# 4   1963                                     1
# 5   1965                                    59
# 6   1968                                    75
# 7   1969                                    18
# 8   1970                                     1
# 9   1971                                     1
# 10  1974                                   166
# 11  1977                                   196
# 12  1980                                   214
# 13  1983                                   274
# 14  1986                                   368
# 15  1990                                   657
# 16  1995                                   698
# 17  1998                                   684
# 18  2002                                   782
# 19  2006                                   726
# 20  2009                                   741
# 21  2013                                   744
# 22  2016                                   711

# %%
fig = px.scatter(jap_colleges_df, x="Year", y="Number of colleges offering Japanese", title='Number of colleges offering Japanese')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="3e9103d6-4dfb-45e5-a462-4d37d4868be2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3e9103d6-4dfb-45e5-a462-4d37d4868be2")) {                    Plotly.newPlot(                        "3e9103d6-4dfb-45e5-a462-4d37d4868be2",                        [{"hovertemplate":"Year=%{x}<br>Number of colleges offering Japanese=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[1958,1959,1960,1961,1963,1965,1968,1969,1970,1971,1974,1977,1980,1983,1986,1990,1995,1998,2002,2006,2009,2013,2016],"xaxis":"x","y":[1,2,32,1,1,59,75,18,1,1,166,196,214,274,368,657,698,684,782,726,741,744,711],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}] ...
